# %%
import re
import requests
import pandas as pd
import numpy as np

# %%
from pandas.io.json import json_normalize

# %% [markdown]
# #### Below is the wikipedia api call for a category search:
#
# `http://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmtitle=Category%3A+machine+learning&cmlimit=max`
#
# `action=query`: query the wikipedia api
#
# `format=json`: return a json format
#
# `list=categorymembers`: List of pages that belong to a given category, ordered by page sort title
#
# `cmtitle=Category%3A+machine+learning`: title of category
#
# `climit=max`: return up to the maximum amount of responses (500)
#
# You may use this to get page titles from the wikipedia API. Things to watch out for:
# * The responses contain categories
# * You will want to fetch articles in those subcategories
#
# The API's detailed documentation can be found [here](https://www.mediawiki.org/wiki/API:Main_page)

# %% [markdown]
# #### Make a function that formats a request for pages of a category

# %%
def categ_format(category):
    get_name = re.sub('\s', '+', category)
    return get_name

# %%
categ_format('machine learning')
# Out:
# 'machine+learning'

# %%
def get_wikipedia_cat(category):
    
    atts = {'action': 'query', 
            'format': 'json', 
            'list': 'categorymembers', 
            'cmtitle': category, 
            'cmlimit': 'max'}

    resp = requests.get('http://en.wikipedia.org/w/api.php', params = atts)
    cats = resp.json()['query']['categorymembers']

    subcats = list(filter(lambda x: x['ns'] == 14, cats))
    pages = list(filter(lambda x: x['ns'] == 0, cats))

    if subcats: 
        for row in subcats:
            pages += get_wikipedia_cat(row['title'])        
    else:
        return pages
        
    return pages

# %%
max_depth = 3

# %%
def get_wikipedia_cat_2(category, depth=0):
    
    atts = {'action': 'query', 
            'format': 'json', 
            'list': 'categorymembers', 
            'cmtitle': category, 
            'cmlimit': 'max'}

    resp = requests.get('http://en.wikipedia.org/w/api.php', params = atts)
    cats = resp.json()['query']['categorymembers']

    subcats = list(filter(lambda x: x['ns'] == 14, cats))
    pages = list(filter(lambda x: x['ns'] == 0, cats))

    if subcats: 
        while depth < max_depth:
            for row in subcats:
                pages += get_wikipedia_cat_2(row['title'], max_depth)
            depth += 1
    else:
        return pages
        
    return pages

# %%
def get_wiki_page(pageid):
    r = requests.get("http://en.wikipedia.org/w/api.php?action=query&\
              format=json&prop=extracts&pageids={}&rvprop=content".format(pageid))
    return r.json()

# %%
pages = get_wikipedia_cat('Category:Machine learning')

# %%
pages_2 = get_wikipedia_cat_2('Category:Business software')

# %%
len(pages_2)

# %%
pages[0]['pageid']

# %%
var = get_wiki_page(pageid)['query']['pages']

# %%
df = json_normalize(var)

# %%
df

# %%
df['43385931.extract']

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.6/site-packages

# %%
from pymongo import MongoClient
client = MongoClient('52.27.26.161', 27016)
db_ref = 'my_database'
client.drop_database(db_ref)
db_ref = client.my_database
mongo_coll = db_ref.my_collection

# %%
client.database_names()
# Out:
# ['admin', 'local', 'pages', 'test']

# %% [markdown]
# db_ref = client.my_database

# %%
db_ref.collection_names()
# Out:
# []

# %% [markdown]
# mongo_coll = db_ref.my_collection

# %% [markdown]
# pages[0]['pageid']

# %%
for i, page in enumerate(pages):
    pageid = str(pages[i]['pageid'])
    page = get_wiki_page(pageid)

    mongo_coll.insert_one(page['query']['pages'][pageid])

print(mongo_coll.count())
# Out:
# 1621

# %%
for i, page in enumerate(pages_2):
    pageid = str(pages_2[i]['pageid'])
    page = get_wiki_page(pageid)

    mongo_coll.insert_one(page['query']['pages'][pageid])

print(mongo_coll.count())
# Out:
# 6258

# %%
all_pages = list(mongo_coll.find())

# %%
all_pages_df = pd.DataFrame(all_pages)

# %%
all_pages_df
# Out:
#                            _id  \
# 0     5a218fc1e15d6e00515f3004
# 1     5a218fc1e15d6e00515f3005
# 2     5a218fc2e15d6e00515f3006
# 3     5a218fc2e15d6e00515f3007
# 4     5a218fc2e15d6e00515f3008
# 5     5a218fc2e15d6e00515f3009
# 6     5a218fc3e15d6e00515f300a
# 7     5a218fc3e15d6e00515f300b
# 8     5a218fc3e15d6e00515f300c
# 9     5a218fc4e15d6e00515f300d
# 10    5a218fc4e15d6e00515f300e
# 11    5a218fc4e15d6e00515f300f
# 12    5a218fc5e15d6e00515f3010
# 13    5a218fc5e15d6e00515f3011
# 14    5a218fc5e15d6e00515f3012
# 15    5a218fc5e15d6e00515f3013
# 16    5a218fc6e15d6e00515f3014
# 17    5a218fc6e15d6e00515f3015
# 18    5a218fc6e15d6e00515f3016
# 19    5a218fc7e15d6e00515f3017
# 20    5a218fc7e15d6e00515f3018
# 21    5a218fc7e15d6e00515f3019
# 22    5a218fc8e15d6e00515f301a
# 23    5a218fc8e15d6e00515f301b
# 24    5a218fc8e15d6e00515f301c
# 25    5a218fc8e15d6e00515f301d
# 26    5a218fc9e15d6e00515f301e
# 27    5a218fc9e15d6e00515f301f
# 28    5a218fc9e15d6e00515f3020
# 29    5a218fcae15d6e00515f3021
# ...                        ...
# 6228  5a21973de15d6e00515f4858
# 6229  5a21973de15d6e00515f4859
# 6230  5a21973de15d6e00515f485a
# 6231  5a21973de15d6e00515f485b
# 6232  5a21973ee15d6e00515f485c
# 6233  5a21973ee15d6e00515f485d
# 6234  5a21973ee15d6e00515f485e
# 6235  5a21973fe15d6e00515f485f
# 6236  5a21973fe15d6e00515f4860
# 6237  5a21973fe15d6e00515f4861
# 6238  5a219740e15d6e00515f4862
# 6239  5a219740e15d6e00515f4863
# 6240  5a219740e15d6e00515f4864
# 6241  5a219740e15d6e00515f4865
# 6242  5a219741e15d6e00515f4866
# 6243  5a219741e15d6e00515f4867
# 6244  5a219741e15d6e00515f4868
# 6245  5a219742e15d6e00515f4869
# 6246  5a219742e15d6e00515f486a
# 6247  5a219742e15d6e00515f486b
# 6248  5a219743e15d6e00515f486c
# 6249  5a219743e15d6e00515f486d
# 6250  5a219743e15d6e00515f486e
# 6251  5a219743e15d6e00515f486f
# 6252  5a219744e15d6e00515f4870
# 6253  5a219744e15d6e00515f4871
# 6254  5a219744e15d6e00515f4872
# 6255  5a219745e15d6e00515f4873
# 6256  5a219745e15d6e00515f4874
# 6257  5a219745e15d6e00515f4875
#
#                                                 extract  ns    pageid  \
# 0     <p><b>Data exploration</b> is an approach simi...   0  43385931
# 1     <p>These datasets are used for machine-learnin...   0  49082762
# 2     <p><b>Machine learning</b> is a field of compu...   0    233488
# 3     <p>The following outline is provided as an ove...   0  53587467
# 4     <p>The <b>accuracy paradox</b> for predictive ...   0   3771060
# 5     <p><b>Action model learning</b> (sometimes abb...   0  43808044
# 6     <p><b>Active learning</b> is a special case of...   0  28801798
# 7     <p><b>Adversarial machine learning</b> is a re...   0  45049676
# 8     <p><b>AIVA</b> (Artificial Intelligence Virtua...   0  52642349
# 9     <p><b>AIXI</b> <span title="Representation in ...   0  30511763
# 10    <p><b>Algorithm selection</b> (sometimes also ...   0  50773876
# 11    <p><b>Algorithmic bias</b> occurs when data us...   0  55817338
# 12    <p><b>Algorithmic inference</b> gathers new de...   0  20890511
# 13    <p><b>AlphaGo</b> is a computer program that p...   0  49242352
# 14    <p><b>AlphaGo Zero</b> is a version of DeepMin...   0  55572262
# 15    <p><b>Apprenticeship learning</b>, or <b>appre...   0  19463198
# 16    <p><b>Automated machine learning</b> or <b>Aut...   0  55843837
# 17    <p>The <b>bag-of-words model</b> is a simplify...   0  14003441
# 18    <p>In computer science, a <b>ball tree</b>, <b...   0  31877832
# 19    <p>In probability and statistics, <b>base rate...   0   9732182
# 20    <p>In machine learning, kernel methods arise f...   0  35867897
# 21    <p><b>Bayesian optimization</b> is a sequentia...   0  40973765
# 22    <p><b>Bayesian structural time series</b> (<b>...   0  50211107
# 23    <p>In statistics and machine learning, the <b>...   0  40678189
# 24    <p><b>BigDL</b> is a deep learning framework, ...   0  55075082
# 25    <p><b>Binary</b> or <b>binomial classification...   0    205393
# 26    <p><b>Bing Predicts</b> is a prediction engine...   0  50646178
# 27    <p>A <b>Bongard problem</b> is a kind of puzzl...   0   1191936
# 28    <p>The <b>Bradley–Terry model</b> is a probabi...   0  44439173
# 29    <p><b>CAFFE</b> (Convolutional Architecture fo...   0  53631046
# ...                                                 ...  ..       ...
# 6228  <p><b>Omgeo</b> is a US financial markets comp...   0   9788607
# 6229  <p><b>OpenMeetings</b> is software used for pr...   0  25034980
# 6230  <p><b>PaperWorks</b> was a computer program in...   0   1699107
# 6231  <p>A <b>pivot chart</b> is a data analysis too...   0   4767593
# 6232  <p><b>plan</b> is a calendar and day planner p...   0   3062614
# 6233  <p><b>PostScript Printer Description (PPD)</b>...   0    456424
# 6234  <p><b>Project KickStart</b> is desktop project...   0  18532395
# 6235  <p><b>QFX</b> is Intuit's proprietary version ...   0  15530023
# 6236  <p><b>Reflex</b> was a 3D building design soft...   0  48254824
# 6237  <p><b>Reliable messaging</b> is the concept of...   0  22628313
# 6238  <p><b>Sage 50 Accounting</b> (<b>US)</b> is a ...   0   2438634
# 6239  <p>A salary calculator is an online applicatio...   0   9636465
# 6240  <p><b>SAP Transport Management System</b> (TMS...   0  19539906
# 6241  <p><b>SASI (Schools Administrative Student Inf...   0    327999
# 6242  <p><b>Sentinel</b> is a software case manageme...   0  26723213
# 6243  <p><b>Sierra Chart</b> is a proprietary comput...   0  26178912
# 6244  <p><b>Sonata</b> was a 3D building design soft...   0  48253668
# 6245  <p><b>Sprog</b> is graphical tool to build Per...   0  14569194
# 6246  <p><i>Super Decisions</i> is decision-making s...   0  47534615
# 6247  <p><b>SuperCalc</b> is a CP/M-80 spreadsheet a...   0   1966364
# 6248  <p><b>Taurus</b> (<b>Transfer and Automated Re...   0   5192200
# 6249  <p><b>TRESS 90</b> (1990–1996) was a Norwegian...   0   1131405
# 6250  <p><b>IBM Unica NetInsight</b> is a web analyt...   0   8838142
# 6251  <p><b>Wang OFFICE</b> was the umbrella brand n...   0   9818995
# 6252  <p><b>WeWorked</b> is web-based time tracking ...   0  51567252
# 6253  <p><b>Whiteboarding</b> is the placement of sh...   0   5794691
# 6254  <p><b>Workflow Resource Planning</b> (<b>WRP</...   0  47513386
# 6255  <p><b>Workflowy</b> is a simple web-based outl...   0  50315118
# 6256  <p>The <b>R1</b> (internally called <b>XCON</b...   0   3234557
# 6257  <p><b>XDB Enterprise Server</b> is a relationa...   0   4260606
#
#                                                  title
# 0                                     Data exploration
# 1       List of datasets for machine learning research
# 2                                     Machine learning
# 3                          Outline of machine learning
# 4                                     Accuracy paradox
# 5                                Action model learning
# 6                   Active learning (machine learning)
# 7                         Adversarial machine learning
# 8                                                 AIVA
# 9                                                 AIXI
# 10                                 Algorithm selection
# 11                                    Algorithmic bias
# 12                               Algorithmic inference
# 13                                             AlphaGo
# 14                                        AlphaGo Zero
# 15                             Apprenticeship learning
# 16                          Automated machine learning
# 17                                  Bag-of-words model
# 18                                           Ball tree
# 19                                           Base rate
# 20    Bayesian interpretation of kernel regularization
# 21                               Bayesian optimization
# 22                     Bayesian structural time series
# 23                              Bias–variance tradeoff
# 24                                               BigDL
# 25                               Binary classification
# 26                                       Bing Predicts
# 27                                     Bongard problem
# 28                                 Bradley–Terry model
# 29                                    Caffe (software)
# ...                                                ...
# 6228                                             Omgeo
# 6229                                      OpenMeetings
# 6230                                        PaperWorks
# 6231                                       Pivot chart
# 6232                           Plan (calendar program)
# 6233                    PostScript Printer Description
# 6234                                 Project KickStart
# 6235                                 QFX (file format)
# 6236                 Reflex (building design software)
# 6237                                Reliable messaging
# 6238                                Sage 50 Accounting
# 6239                                 Salary calculator
# 6240                   SAP Transport management system
# 6241                                   SASI (software)
# 6242                                    Sentinel (FBI)
# 6243                                      Sierra Chart
# 6244                 Sonata (building design software)
# 6245                                  Sprog (software)
# 6246                                   Super Decisions
# 6247                                         SuperCalc
# 6248                         TAURUS (share settlement)
# 6249                                          Tress 90
# 6250                              IBM Unica NetInsight
# 6251                                       Wang OFFICE
# 6252                                          WeWorked
# 6253                                     Whiteboarding
# 6254                        Workflow Resource Planning
# 6255                                         Workflowy
# 6256                                              Xcon
# 6257                             XDB Enterprise Server
#
# [6258 rows x 5 columns]

# %%
all_pages_df.to_pickle('all_pages_df.p')
